# %% [markdown]
# <h2><span style="color:gray">ipyrad-analysis toolkit: </span>treeslider downstream analyses</h2>

# %% [markdown]
# Once you've run treeslider you now have a distribution of gene trees that you can use as input to a multi-locu species tree or network inference program. Here I demonstrate how to input your data to **astral**.

# %% [markdown]
# ### Required software

# %%
# conda install ipyrad -c bioconda
# conda install toytree -c eaton-lab

# %%
import pandas as pd
import toytree

# %% [markdown]
# ### Short Tutorial:

# %% [markdown]
# #### Load the tree_table data

# %%
# load the tree table from CSV
tree_table = pd.read_csv(
    "./analysis-treeslider/test.tree_table.csv",
    index_col=0,
)

# %%
# examine top of table
tree_table.head()
# Out:
#    scaffold    start       end  sites  snps  samples  missing  \
# 0         2        0   2000000  13263   155        9      0.0
# 1         2  2000000   4000000  10544   112        9      0.0
# 2         2  4000000   6000000   5544    46        9      0.0
# 3         2  6000000   8000000  12777   138        9      0.0
# 4         2  8000000  10000000  14441   166        9      0.0
#
#                                                 tree
# 0  (sagr:0.00343708,(oleo:0.00266064,(mini:0.0020...
# 1  (fusi-N:0.00441769,reference:0.0186764,((bran:...
# 2  (virg:0.00297301,fusi-N:0.00243431,(oleo:0.003...
# 3  (fusi-N:0.00283693,(bran:0.00363545,reference:...
# 4  (bran:0.00446094,reference:0.0119105,(fusi-S:0...

# %% [markdown]
# ### Write the trees column to a file

# %%
outfile = open("trees.nwk", "w")
outfile.write("\n".join(tree_table.tree.tolist()))
outfile.close()

# %% [markdown]
# ### Get Astral
# The following command will download and unzip Astral into the current directory. A binary to call the program *astral* will be located in the Astral directory.

# %%
# %%bash
# wget -q https://github.com/smirarab/ASTRAL/raw/master/Astral.5.6.3.zip
# unzip -qo Astral.5.6.3

# %% [markdown]
# ### Run Astral
# This will write the results (stdout) to a file called astral.tre, and it will write other information printed to the screen (stderr) to a file called astral.err. By default astral runs 100 bootstrap replicates by gene-tree resampling. To turn on gene and site resampling would require inputting the bootstrap files, which we did not currently save (we could...).

# %%
# %%bash
# java -jar Astral/astral.5.6.3.jar -i trees.nwk > astral.tre 2>astral.err

# %% [markdown]
# ### Plot astral species tree

# %%
tre = toytree.rtree.coaltree(10)
tre.

# %%
tre.rotate_node(names=["r0", "r1", "r2"])

# %%
tre.draw(node_labels=True);
# Out:
# <div class="toyplot" id="t9f0f73190e2f462d89fdd7d979e853b4" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="275.0px" id="t584e1c6914574a43baf3dc4b2672c3c6" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 260.0 275.0" width="260.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tb13d9bfb3b3048699b6d94151b233bd5"><clipPath id="t75d4b1aad4ee4d7a9fa34172d2d098e9"><rect height="215.0" width="200.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t75d4b1aad4ee4d7a9fa34172d2d098e9)"><g class="toyplot-mark-Text" id="td411deddf1804c6187b2c04b1d84e259"><g class="toyplot-Series"><g class="toyplot-Datum" transform="translate(195.45454545454544,218.86291179596174)"><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:11.0px;font-weight:normal;opacity:1;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="2.8104999999999993">r0</text></g><g class="toyplot-Datum" transform="translate(195.45454545454544,200.78226473019248)"><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:11.0px;font-weight:normal;opacity:1;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="2.8104999999999993">r1</text></g><g class="toyplot-Datum" transform="translate(195.45454545454544,182.70161766442322)"><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:11.0px;font-weight:normal;opacity:1;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="2.8104999999999993">r2</text></g><g class="toyplot-Datum" transform="translate(195.45454545454544,164.6209705986539)"><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:11.0px;font-weight:normal;opacity:1;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="2.8104999999999993">r3</text></g><g class="toyplot-Datum" transform="translate(195.45454545454547,146.54032353288463)"><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:11.0px;font-weight:normal;opacity:1;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="2.8104999999999993">r4</text></g><g class="toyplot-Datum" transform="translate(195.45454545454547,128.45967646711534)"><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:11.0px;font-weight:normal;opacity:1;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="2.8104999999999993">r5</text></g><g class="toyplot-Datum" transform="translate(195.45454545454547,110.37902940134609)"><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:11.0px;font-weight:normal;opacity:1;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="2.8104999999999993">r6</text></g><g class="toyplot-Datum" transform="translate(195.45454545454547,92.2983823355768)"><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:11.0px;font-weight:normal;opacity:1;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="2.8104999999999993">r7</text></g><g class="toyplot-Datum" transform="translate(195.45454545454544,74.2177352698075)"><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:11.0px;font-weight:normal;opacity:1;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="2.8104999999999993">r8</text></g><g class="toyplot-Datum" transform="translate(195.45454545454547,56.137088204038236)"><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:11.0px;font-weight:normal;opacity:1;stroke:none;vertical-a ...

# %%
tre = toytree.tree("astral.tre").root('reference')
tre.draw(node_labels="support", tip_labels_align=True);
# Out:
# ---------------------------------------------------------------------------
# NewickError                               Traceback (most recent call last)
# <ipython-input-60-40b2dc83ebdf> in <module>
# ----> 1 tre = toytree.tree("astral.tre").root('reference')
#       2 tre.draw(node_labels="support", tip_labels_align=True);
#
# ~/Documents/toytree/toytree/Toytree.py in __init__(self, newick, tree_format, fixed_order)
#      54         # prase a str, URL, or file
#      55         elif isinstance(newick, (str, bytes)):
# ---> 56             self.treenode = TreeParser(newick, tree_format).treenodes[0]
#      57
#      58         # make an empty tree
#
# ~/Documents/toytree/toytree/TreeParser.py in __init__(self, intree, tree_format, multitree, debug)
#      64         # parse intree
#      65         if not self.debug:
# ---> 66             self._run()
#      67
#      68
#
# ~/Documents/toytree/toytree/TreeParser.py in _run(self)
#      80
#      81             # parse newick strings to treenodes list
# ---> 82             self.get_treenodes()
#      83
#      84             # apply names from tdict
#
# ~/Documents/toytree/toytree/TreeParser.py in get_treenodes(self)
#     148
#     149             # extract one tree
# --> 150             self.treenodes.append(extractor.newick_from_string())
#     151
#     152         else:
#
# ~/Documents/toytree/toytree/TreeParser.py in newick_from_string(self)
#     251                         closing_internal = closing_internal.rstrip(";")
#     252                         # read internal node data and go up one level
# --> 253                         self.apply_node_data(closing_internal, "internal")
#     254                         self.current_parent = self.current_parent.up
#     255         return self.root
#
# ~/Documents/toytree/toytree/TreeParser.py in apply_node_data(self, subnw, node_type)
#     306                     self.current_node.add_feature(fname, fvalue)
#     307         else:
# --> 308             raise NewickError("Unexpected newick format {}".format(subnw))
#     309
#     310
#
# NewickError: Unexpected newick format '[q1=0.4761904761904762;q2=0.2619047619047619;q3=0.2619047619047619;f1=13.333333333333334;f2=7.333333333333334;f3=7.333333333333334;pp1=0.8444981624253073;pp2=0.07775091878734611;pp3=0.07775091878734611;QC=6;EN=28.0]':0.2102954088363608

# %% [markdown]
# ### Plot astral species tree with quartet supports
# Not yet supported in toytree, what a wonky file format...
