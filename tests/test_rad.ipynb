# %% [markdown]
# # _ipyrad_ testing tutorial

# %% [markdown]
# ### Getting started
# Import _ipyrad_ and remove previous test files if they are already present

# %%
## import modules
import ipyrad as ip      ## for RADseq assembly
print ip.__version__     ## print version

## clear data from test directory if it already exists
import shutil
import os
if os.path.exists("./test_rad/"):
    shutil.rmtree("./test_rad/")
# Out:
# 0.0.62

# %% [markdown]
# ### Assembly and Sample objects
#
# Assembly and Sample objects are used by _ipyrad_ to access data stored on disk and to manipulate it. Each biological sample in a data set is represented in a Sample object, and a set of Samples is stored inside an Assembly object. The Assembly object has functions to assemble the data, and stores a log of all steps performed and the resulting statistics of those steps. Assembly objects can be copied or merged to allow branching events where different parameters can subsequently be applied to different Assemblies going forward. Examples of this are shown below.
#
# To create an Assembly object call `ip.Assembly()` and pass a name for the data set. An Assembly object does not initially contain Samples, they will be created either by linking fastq files to the Assembly object if data are already demultiplexed, or by running `step1()` to demultiplex raw data files, as shown below.

# %%
## create an Assembly object called data1. 
data1 = ip.Assembly("data1")

## The object will be saved to disk using its assigned name
print "Assembly object named", data1.name
# Out:
# Assembly object named data1

# %% [markdown]
# ### Modifying assembly parameters
# All of the parameter settings are linked to an Assembly object, which has a set of default parameters when it is created. These can be viewed using the `get_params()` function. To get more detailed information about all parameters use `ip.get_params_info()` or to select a single parameter use `ip.get_params_info(3)`. Assembly objects have a function `set_params()` that can be used to modify parameters.

# %%
## modify parameters for this Assembly object
data1.set_params(1, "./test_rad")
#data1.set_params(2, "./data/sim_rad_test_R1_.fastq.gz")
#data1.set_params(3, "./data/sim_rad_test_barcodes.txt")
data1.set_params(2, "~/Dropbox/UO_C353_1.fastq.part-aa.gz")
data1.set_params(3, "/home/deren/Dropbox/Viburnum_revised.barcodes")
data1.set_params(7, 3)
data1.set_params(10, 'rad')

## print the new parameters to screen
data1.get_params()
# Out:
#   1   working_directory             ./test_rad
#   2   raw_fastq_path                /home/deren/Dropbox/UO_C353_1.fastq.part-aa.gz
#   3   barcodes_path                 /home/deren/Dropbox/Viburnum_revised.barcodes
#   4   sorted_fastq_path
#   5   restriction_overhang          ('TGCAG', '')
#   6   max_low_qual_bases            5
#   7   N_processors                  3
#   8   mindepth_statistical          6
#   9   mindepth_majrule              6
#   10  datatype                      rad
#   11  clust_threshold               0.85
#   12  minsamp                       4
#   13  max_shared_heterozygosity     0.25
#   14  prefix_outname                data1
#   15  phred_Qscore_offset           33
#   16  max_barcode_mismatch          1
#   17  filter_adapters               0
#   18  filter_min_trim_len           35
#   19  ploidy                        2
#   20  max_stack_size                1000
#   21  max_Ns_consens                5
#   22  max_Hs_consens                8
#   23  max_SNPs_locus                (100, 100)
#   24  max_Indels_locus              (5, 99)
#   25  trim_overhang                 (1, 2, 2, 1)
#   26  hierarchical_clustering       0

# %% [markdown]
# ### Starting data
# If the data are already demultiplexed then fastq files can be linked directly to the Data object, which in turn will create Sample objects for each fastq file (or pair of fastq files for paired data). The files may be gzip compressed. If the data are not demultiplexed then you will have to run the step1 function below to demultiplex the raw data.

# %%
## This would link fastq files from the 'sorted_fastq_path' if present
## Here it does nothing b/c there are no files in the sorted_fastq_path
data1.link_fastqs()

# %% [markdown]
# ### Step 1: Demultiplex the raw data files
# This uses the barcodes information to demultiplex reads in data files found in the 'raw_fastq_path'. It will create a Sample object for each sample that will be stored in the Assembly object.

# %%
# %%time
## run step 1 to demultiplex the data
data1.step1()

## print the results for each Sample in data1
print data1.stats.head()
# Out:
#                             state  reads_raw  reads_filtered  clusters_total  \
# FGXCONTROL                      1     126378             NaN             NaN
# acerfolium_ELS88                1      23232             NaN             NaN
# acutifolium_D11_MEX_005         1      12292             NaN             NaN
# acutifolium_DRY3_MEX_006        1      33137             NaN             NaN
# amplificatum_D3_SAN_156003      1      22284             NaN             NaN
#
#                             clusters_kept  hetero_est  error_est  \
# FGXCONTROL                            NaN         NaN        NaN
# acerfolium_ELS88                      NaN         NaN        NaN
# acutifolium_D11_MEX_005               NaN         NaN        NaN
# acutifolium_DRY3_MEX_006              NaN         NaN        NaN
# amplificatum_D3_SAN_156003            NaN         NaN        NaN
#
#                             reads_consens
# FGXCONTROL                            NaN
# acerfolium_ELS88                      NaN
# acutifolium_D11_MEX_005               NaN
# acutifolium_DRY3_MEX_006              NaN
# amplificatum_D3_SAN_156003            NaN
# CPU times: user 20.1 ms, sys: 51 µs, total: 20.1 ms
# Wall time: 20.9 ms

# %%
print data1.stats.reads_raw
# Out:
# FGXCONTROL                    126378
# acerfolium_ELS88               23232
# acutifolium_D11_MEX_005        12292
# acutifolium_DRY3_MEX_006       33137
# amplificatum_D3_SAN_156003     22284
# anamensis_C6_PWS_2094           6685
# beccarii_combinedX             11901
# betulifolium                   11792
# bitchuense_combined            14212
# carlesii_D1_BP_001             27172
# cassinoides_ELS2               14056
# cassinoides_ELS29              12591
# cassinoides_ELS3               10132
# cassinoides_ELS50              11051
# cassinoides_ELS77              17391
# cassinoides_ELS79              14225
# cassinoides_LS54                7920
# cassinoides_YU08                5879
# cinnamomifolium_PWS2105X       22479
# clemensiae_DRY6_PWS_2135       21398
# coriaceum_combined             16501
# cylindricum_DRY1_WC_268        40868
# davidii_D32_WC_269             22173
# dentatum_AA_5070_1A            11451
# dentatum_ELS15                 14002
# dentatum_ELS27                 35581
# dentatum_ELS4                  26792
# dentatum_ELS52                 25205
# dentatum_ELS72                 18476
# dentatum_ELS82                 26842
#                                ...
# propiinquum_combined           17025
# propinquum_DRY4_WC_276         22628
# prunifolium_AA_22586A          20650
# prunifolium_ELS57              16386
# punctatum_D19_PWS_2097         22294
# recognitum_AA_1471_83B         15531
# rhytidophyllum                 17229
# rufidulum_AA_21418A            13407
# rufidulum_ELS1                 10705
# rufidulum_ELS17                12412
# rufidulum_ELS25                12941
# sambucina_D20_PWS_2100         16882
# sargentii_RCW19                 9648
# sempervirens_combined          10040
# setigerum                      21794
# sieboldii_AA_616_6B             8405
# sulc_acut_hyb_D7_MEX_001       26277
# sulc_acut_hyb_D8_MEX_002       20250
# sulcatum_D10_MEX_004           39518
# sulcatum_D9_MEX_003            45904
# suspensum_C5_MJD_111711        12734
# sympodiale_D18_KFC_1932        24856
# taiwanianum_TW1_KFC_1952       38238
# tashiori_D30_TET_YAH           37508
# tinus_D33_WC_277               21717
# triphyllum_D13_PWS_1783        13802
# urceolatum_MJD_Japan_8         13891
# veitchii                       15273
# vernicosum_D21_PWS_2123        14880
# wrightii_D31_MJDJP_1           15786
# Name: reads_raw, dtype: float64

# %% [markdown]
# ### Step 2: Filter reads
# If for some reason we wanted to execute on just a subsample of our data, we could do this by selecting only certain samples to call the `step2` function on. Because `step2` is a function of `data`, it will always execute with the parameters that are linked to `data`.

# %%
# %%time
## example of ways to run step 2 to filter and trim reads
#data1.step2("1B_0")                 ## run on a single sample
#data1.step2(["1B_0", "1C_0"])       ## run on one or more samples
data1.step2(force=True)              ## run on all samples, skipping finished ones

## print the results
print data1.stats
# Out:
#                             state  reads_raw  reads_filtered  clusters_total  \
# FGXCONTROL                      2     126378          103847             NaN
# acerfolium_ELS88                2      23232           17800             NaN
# acutifolium_D11_MEX_005         2      12292           10140             NaN
# acutifolium_DRY3_MEX_006        2      33137           25261             NaN
# amplificatum_D3_SAN_156003      2      22284           17305             NaN
# anamensis_C6_PWS_2094           2       6685            5084             NaN
# beccarii_combinedX              2      11901           10086             NaN
# betulifolium                    2      11792            9597             NaN
# bitchuense_combined             2      14212           11994             NaN
# carlesii_D1_BP_001              2      27172           23293             NaN
# cassinoides_ELS2                2      14056           11883             NaN
# cassinoides_ELS29               2      12591            9800             NaN
# cassinoides_ELS3                2      10132            8086             NaN
# cassinoides_ELS50               2      11051            8888             NaN
# cassinoides_ELS77               2      17391           13218             NaN
# cassinoides_ELS79               2      14225           10386             NaN
# cassinoides_LS54                2       7920            5820             NaN
# cassinoides_YU08                2       5879            4527             NaN
# cinnamomifolium_PWS2105X        2      22479           18427             NaN
# clemensiae_DRY6_PWS_2135        2      21398           17533             NaN
# coriaceum_combined              2      16501           13378             NaN
# cylindricum_DRY1_WC_268         2      40868           31633             NaN
# davidii_D32_WC_269              2      22173           18781             NaN
# dentatum_AA_5070_1A             2      11451            9848             NaN
# dentatum_ELS15                  2      14002           11686             NaN
# dentatum_ELS27                  2      35581           28510             NaN
# dentatum_ELS4                   2      26792           21357             NaN
# dentatum_ELS52                  2      25205           19831             NaN
# dentatum_ELS72                  2      18476           14620             NaN
# dentatum_ELS82                  2      26842           21768             NaN
# ...                           ...        ...             ...             ...
# propiinquum_combined            2      17025           13188             NaN
# propinquum_DRY4_WC_276          2      22628           18727             NaN
# prunifolium_AA_22586A           2      20650           17703             NaN
# prunifolium_ELS57               2      16386           13978             NaN
# punctatum_D19_PWS_2097          2      22294           17786             NaN
# recognitum_AA_1471_83B          2      15531           12786             NaN
# rhytidophyllum                  2      17229           14246             NaN
# rufidulum_AA_21418A             2      13407           10103             NaN
# rufidulum_ELS1                  2      10705            8590             NaN
# rufidulum_ELS17                 2      12412            8808             NaN
# rufidulum_ELS25                 2      12941            9393             NaN
# sambucina_D20_PWS_2100          2      16882           14105             NaN
# sargentii_RCW19                 2       9648            8137             NaN
# sempervirens_combined           2      10040            8242             NaN
# setigerum                       2      21794           17593             NaN
# sieboldii_AA_616_6B             2       8405            6948             NaN
# sulc_acut_hyb_D7_MEX_001        2      26277           20955             NaN
# sulc_acut_hyb_D8_MEX_002        2      20250           15438             NaN
# sulcatum_D10_MEX_004            2      39518           28005             NaN
# sulcatum_D9_MEX_003             2      45904           33968             NaN
# suspensum_C5_MJD_111711         2      12734           10277             NaN
# sympodiale_D18_KFC_1932         2      24856           20135             NaN
# taiwanianum_TW1_KFC_1952        2      38238           30240             NaN
# tashiori_D30_TET_YAH            2      37508           29260             NaN
# tinus_D33_WC_277                2      21717           17234             NaN
# triphyllum_D13_PWS_1783         2      13802           11631             NaN
# urceolatum_MJD_Japan_8          2      13891           11014             NaN
# veitchii                        2      15273           12965             NaN
# vernicosum_D21_PWS_2123         2      14880           12105             NaN
# wrightii_D31_MJDJP_1            2      15786           13231             NaN
#
#                             clusters_kept  hetero_est  error_est  \
# FGXCONTROL                            NaN         NaN        NaN
# acerfolium_ELS88                      NaN         NaN        NaN
# acutifolium_D11_MEX_005               NaN         NaN        NaN
# acutifolium_DRY3_MEX_006              NaN         NaN        NaN
# amplificatum_D3_SAN_156003            NaN         NaN        NaN
# anamensis_C6_PWS_2094                 NaN         NaN        NaN
# beccarii_combinedX                    NaN         NaN        NaN
# betulifolium                          NaN         NaN        NaN
# bitchuense_combined                   NaN         NaN        NaN
# carlesii_D1_BP_001                    NaN         NaN        NaN
# cassinoides_ELS2                      NaN         NaN        NaN
# cassinoides_ELS29                     NaN         NaN        NaN
# cassinoides_ELS3                      NaN         NaN        NaN
# cassinoides_ELS50                     NaN         NaN        NaN
# cassinoides_ELS77                     NaN         NaN        NaN
# cassinoides_ELS79                     NaN         NaN        NaN
# cassinoides_LS54                      NaN         NaN        NaN
# cassinoides_YU08                      NaN         NaN        NaN
# cinnamomifolium_PWS2105X              NaN         NaN        NaN
# clemensiae_DRY6_PWS_2135              NaN         NaN        NaN
# coriaceum_combined                    NaN         NaN        NaN
# cylindricum_DRY1_WC_268               NaN         NaN        NaN
# davidii_D32_WC_269                    NaN         NaN        NaN
# dentatum_AA_5070_1A                   NaN         NaN        NaN
# dentatum_ELS15                        NaN         NaN        NaN
# dentatum_ELS27                        NaN         NaN        NaN
# dentatum_ELS4                         NaN         NaN        NaN
# dentatum_ELS52                        NaN         NaN        NaN
# dentatum_ELS72                        NaN         NaN        NaN
# dentatum_ELS82                        NaN         NaN        NaN
# ...                                   ...         ...        ...
# propiinquum_combined                  NaN         NaN        NaN
# propinquum_DRY4_WC_276                NaN         NaN        NaN
# prunifolium_AA_22586A                 NaN         NaN        NaN
# prunifolium_ELS57                     NaN         NaN        NaN
# punctatum_D19_PWS_2097                NaN         NaN        NaN
# recognitum_AA_1471_83B                NaN         NaN        NaN
# rhytidophyllum                        NaN         NaN        NaN
# rufidulum_AA_21418A                   NaN         NaN        NaN
# rufidulum_ELS1                        NaN         NaN        NaN
# rufidulum_ELS17                       NaN         NaN        NaN
# rufidulum_ELS25                       NaN         NaN        NaN
# sambucina_D20_PWS_2100                NaN         NaN        NaN
# sargentii_RCW19                       NaN         NaN        NaN
# sempervirens_combined                 NaN         NaN        NaN
# setigerum                             NaN         NaN        NaN
# sieboldii_AA_616_6B                   NaN         NaN        NaN
# sulc_acut_hyb_D7_MEX_001              NaN         NaN        NaN
# sulc_acut_hyb_D8_MEX_002              NaN         NaN        NaN
# sulcatum_D10_MEX_004                  NaN         NaN        NaN
# sulcatum_D9_MEX_003                   NaN         NaN        NaN
# suspensum_C5_MJD_111711               NaN         NaN        NaN
# sympodiale_D18_KFC_1932               NaN         NaN        NaN
# taiwanianum_TW1_KFC_1952              NaN         NaN        NaN
# tashiori_D30_TET_YAH                  NaN         NaN        NaN
# tinus_D33_WC_277                      NaN         NaN        NaN
# triphyllum_D13_PWS_1783               NaN         NaN        NaN
# urceolatum_MJD_Japan_8                NaN         NaN        NaN
# veitchii                              NaN         NaN        NaN
# vernicosum_D21_PWS_2123               NaN         NaN        NaN
# wrightii_D31_MJDJP_1                  NaN         NaN        NaN
#
#                             reads_consens
# FGXCONTROL                            NaN
# acerfolium_ELS88                      NaN
# acutifolium_D11_MEX_005               NaN
# acutifolium_DRY3_MEX_006              NaN
# amplificatum_D3_SAN_156003            NaN
# anamensis_C6_PWS_2094                 NaN
# beccarii_combinedX                    NaN
# betulifolium                          NaN
# bitchuense_combined                   NaN
# carlesii_D1_BP_001                    NaN
# cassinoides_ELS2                      NaN
# cassinoides_ELS29                     NaN
# cassinoides_ELS3                      NaN
# cassinoides_ELS50                     NaN
# cassinoides_ELS77                     NaN
# cassinoides_ELS79                     NaN
# cassinoides_LS54                      NaN
# cassinoides_YU08                      NaN
# cinnamomifolium_PWS2105X              NaN
# clemensiae_DRY6_PWS_2135              NaN
# coriaceum_combined                    NaN
# cylindricum_DRY1_WC_268               NaN
# davidii_D32_WC_269                    NaN
# dentatum_AA_5070_1A                   NaN
# dentatum_ELS15                        NaN
# dentatum_ELS27                        NaN
# dentatum_ELS4                         NaN
# dentatum_ELS52                        NaN
# dentatum_ELS72                        NaN
# dentatum_ELS82                        NaN
# ...                                   ...
# propiinquum_combined                  NaN
# propinquum_DRY4_WC_276                NaN
# prunifolium_AA_22586A                 NaN
# prunifolium_ELS57                     NaN
# punctatum_D19_PWS_2097                NaN
# recognitum_AA_1471_83B                NaN
# rhytidophyllum                        NaN
# rufidulum_AA_21418A                   NaN
# rufidulum_ELS1                        NaN
# rufidulum_ELS17                       NaN
# rufidulum_ELS25                       NaN
# sambucina_D20_PWS_2100                NaN
# sargentii_RCW19                       NaN
# sempervirens_combined                 NaN
# setigerum                             NaN
# sieboldii_AA_616_6B                   NaN
# sulc_acut_hyb_D7_MEX_001              NaN
# sulc_acut_hyb_D8_MEX_002              NaN
# sulcatum_D10_MEX_004                  NaN
# sulcatum_D9_MEX_003                   NaN
# suspensum_C5_MJD_111711               NaN
# sympodiale_D18_KFC_1932               NaN
# taiwanianum_TW1_KFC_1952              NaN
# tashiori_D30_TET_YAH                  NaN
# tinus_D33_WC_277                      NaN
# triphyllum_D13_PWS_1783               NaN
# urceolatum_MJD_Japan_8                NaN
# veitchii                              NaN
# vernicosum_D21_PWS_2123               NaN
# wrightii_D31_MJDJP_1                  NaN
#
# [96 rows x 8 columns]
# CPU times: user 1min 57s, sys: 3.42 s, total: 2min 1s
# Wall time: 3min 28s

# %% [markdown]
# ### Step 3: clustering within-samples
#
# Let's imagine at this point that we are interested in clustering our data at two different clustering thresholds. We will try 0.90 and 0.85. First we need to make a copy the Assembly object. This will inherit the locations of the data linked in the first object, but diverge in any future applications to the object. Thus, they can share the same working directory, and will inherit shared files, but create divergently linked files within this directory. You can view the directories linked to an Assembly object with the `.dirs` argument, shown below.

# %%
## create a copy of our Assemlbly object
data2 = data1.copy(newname="test2")

## set clustering threshold to 0.90
data2.set_params(11, 0.90)

## look at inherited parameters
data2.get_params()

# %%
import ipyrad as ip
data1 = ip.load_assembly("test_rad/data1.assembly")

# %%
## run step 3 to cluster reads within samples using vsearch
#data1.step3(['2E_0'], force=True, preview=True)  # ["2H_0", "2G_0"])
data1.step3()
## print the results
print data1.stats
# Out:
# clustering 96 samples on 3 processors
# inclusts <listiterator object at 0x7f87176e7290>
# 0 250 3237
# inclusts <listiterator object at 0x7f87176e7290>
# 250 500 3237
# inclusts <listiterator object at 0x7f87176e7290>
# 500 750 3237
# inclusts <listiterator object at 0x7f87176e7290>
# 750 1000 3237
# inclusts <listiterator object at 0x7f87176e7290>
# 1000 1250 3237
# inclusts <listiterator object at 0x7f87176e7290>
# 1250 1500 3237
# inclusts <listiterator object at 0x7f87176e7290>
# 1500 1750 3237
# inclusts <listiterator object at 0x7f87176e7290>
# 1750 2000 3237
# inclusts <listiterator object at 0x7f87176e7290>
# 2000 2250 3237
# inclusts <listiterator object at 0x7f87176e7290>
# 2250 2500 3237
# inclusts <listiterator object at 0x7f87176e7290>
# 2500 2750 3237
# inclusts <listiterator object at 0x7f87176e7290>
# 2750 3000 3237
# inclusts <listiterator object at 0x7f87176e7290>
# 3000 3250 3237
# inclusts <listiterator object at 0x7f87176e7290>
# 0 250 3045
# inclusts <listiterator object at 0x7f87176e7290>
# 250 500 3045
# inclusts <listiterator object at 0x7f87176e7290>
# 500 750 3045
# inclusts <listiterator object at 0x7f87176e7290>
# 750 1000 3045
# inclusts <listiterator object at 0x7f87176e7290>
# 1000 1250 3045
# inclusts <listiterator object at 0x7f87176e7290>
# 1250 1500 3045
# inclusts <listiterator object at 0x7f87176e7290>
# 1500 1750 3045
# inclusts <listiterator object at 0x7f87176e7290>
# 1750 2000 3045
# inclusts <listiterator object at 0x7f87176e7290>
# 2000 2250 3045
# inclusts <listiterator object at 0x7f87176e7290>
# 2250 2500 3045
# inclusts <listiterator object at 0x7f87176e7290>
# 2500 2750 3045
# inclusts <listiterator object at 0x7f87176e7290>
# 2750 3000 3045
# inclusts <listiterator object at 0x7f87176e7290>
# 3000 3250 3045
# inclusts <listiterator object at 0x7f871769df90>
# 0 250 3793
# inclusts <listiterator object at 0x7f871769df90>
# 250 500 3793
# inclusts <listiterator object at 0x7f871769df90>
# 500 750 3793
# inclusts <listiterator object at 0x7f871769df90>
# 750 1000 3793
# inclusts <listiterator object at 0x7f871769df90>
# 1000 1250 3793
# inclusts <listiterator object at 0x7f871769df90>
# 1250 1500 3793
# inclusts <listiterator object at 0x7f871769df90>
# 1500 1750 3793
# inclusts <listiterator object at 0x7f871769df90>
# 1750 2000 3793
# inclusts <listiterator object at 0x7f871769df90>
# 2000 2250 3793
# inclusts <listiterator object at 0x7f871769df90>
# 2250 2500 3793
# inclusts <listiterator object at 0x7f871769df90>
# 2500 2750 3793
# inclusts <listiterator object at 0x7f871769df90>
# 2750 3000 3793
# inclusts <listiterator object at 0x7f871769df90>
# 3000 3250 3793
# inclusts <listiterator object at 0x7f871769df90>
# 3250 3500 3793
# inclusts <listiterator object at 0x7f871769df90>
# 3500 3750 3793
# inclusts <listiterator object at 0x7f871769df90>
# 3750 4000 3793
# inclusts <listiterator object at 0x7f874b081150>
# 0 250 3613
# inclusts <listiterator object at 0x7f874b081150>
# 250 500 3613
# inclusts <listiterator object at 0x7f874b081150>
# 500 750 3613
# inclusts <listiterator object at 0x7f874b081150>
# 750 1000 3613
# inclusts <listiterator object at 0x7f874b081150>
# 1000 1250 3613
# inclusts <listiterator object at 0x7f874b081150>
# 1250 1500 3613
# inclusts <listiterator object at 0x7f874b081150>
# 1500 1750 3613
# inclusts <listiterator object at 0x7f874b081150>
# 1750 2000 3613
# inclusts <listiterator object at 0x7f874b081150>
# 2000 2250 3613
# inclusts <listiterator object at 0x7f874b081150>
# 2250 2500 3613
# inclusts <listiterator object at 0x7f874b081150>
# 2500 2750 3613
# inclusts <listiterator object at 0x7f874b081150>
# 2750 3000 3613
# inclusts <listiterator object at 0x7f874b081150>
# 3000 3250 3613
# inclusts <listiterator object at 0x7f874b081150>
# 3250 3500 3613
# inclusts <listiterator object at 0x7f874b081150>
# 3500 3750 3613
# inclusts <listiterator object at 0x7f871769df90>
# 0 250 4479
# inclusts <listiterator object at 0x7f871769df90>
# 250 500 4479
# inclusts <listiterator object at 0x7f871769df90>
# 500 750 4479
# inclusts <listiterator object at 0x7f871769df90>
# 750 1000 4479
# inclusts <listiterator object at 0x7f871769df90>
# 1000 1250 4479
# inclusts <listiterator object at 0x7f871769df90>
# 1250 1500 4479
# inclusts <listiterator object at 0x7f871769df90>
# 1500 1750 4479
# inclusts <listiterator object at 0x7f871769df90>
# 1750 2000 4479
# inclusts <listiterator object at 0x7f871769df90>
# 2000 2250 4479
# inclusts <listiterator object at 0x7f871769df90>
# 2250 2500 4479
# inclusts <listiterator object at 0x7f871769df90>
# 2500 2750 4479
# inclusts <listiterator object at 0x7f871769df90>
# 2750 3000 4479
# inclusts <listiterator object at 0x7f871769df90>
# 3000 3250 4479
# inclusts <listiterator object at 0x7f871769df90>
# 3250 3500 4479
# inclusts <listiterator object at 0x7f871769df90>
# 3500 3750 4479
# inclusts <listiterator object at 0x7f871769df90>
# 3750 4000 4479
# inclusts <listiterator object at 0x7f871769df90>
# 4000 4250 4479
# inclusts <listiterator object at 0x7f871769df90>
# 4250 4500 4479
# inclusts <listiterator object at 0x7f874b081150>
# 0 250 4607
# inclusts <listiterator object at 0x7f874b081150>
# 250 500 4607
# inclusts <listiterator object at 0x7f874b081150>
# 500 750 4607
# inclusts <listiterator object at 0x7f874b081150>
# 750 1000 4607
# inclusts <listiterator object at 0x7f874b081150>
# 1000 1250 4607
# inclusts <listiterator object at 0x7f874b081150>
# 1250 1500 4607
# inclusts <listiterator object at 0x7f874b081150>
# 1500 1750 4607
# inclusts <listiterator object at 0x7f874b081150>
# 1750 2000 4607
# inclusts <listiterator object at 0x7f874b081150>
# 2000 2250 4607
# inclusts <listiterator object at 0x7f874b081150>
# 2250 2500 4607
# inclusts <listiterator object at 0x7f874b081150>
# 2500 2750 4607
# inclusts <listiterator object at 0x7f874b081150>
# 2750 3000 4607
# inclusts <listiterator object at 0x7f874b081150>
# 3000 3250 4607
# inclusts <listiterator object at 0x7f874b081150>
# 3250 3500 4607
# inclusts <listiterator object at 0x7f874b081150>
# 3500 3750 4607
# inclusts <listiterator object at 0x7f874b081150>
# 3750 4000 4607
# inclusts <listiterator object at 0x7f874b081150>
# 4000 4250 4607
# inclusts <listiterator object at 0x7f874b081150>
# 4250 4500 4607
# inclusts <listiterator object at 0x7f874b081150>
# 4500 4750 4607
# inclusts <listiterator object at 0x7f871769df90>
# 0 250 4874
# inclusts <listiterator object at 0x7f871769df90>
# 250 500 4874
# inclusts <listiterator object at 0x7f871769df90>
# 500 750 4874
# inclusts <listiterator object at 0x7f871769df90>
# 750 1000 4874
# inclusts <listiterator object at 0x7f871769df90>
# 1000 1250 4874
# inclusts <listiterator object at 0x7f871769df90>
# 1250 1500 4874
# inclusts <listiterator object at 0x7f871769df90>
# 1500 1750 4874
# inclusts <listiterator object at 0x7f871769df90>
# 1750 2000 4874
# inclusts <listiterator object at 0x7f871769df90>
# 2000 2250 4874
# inclusts <listiterator object at 0x7f871769df90>
# 2250 2500 4874
# inclusts <listiterator object at 0x7f871769df90>
# 2500 2750 4874
# inclusts <listiterator object at 0x7f871769df90>
# 2750 3000 4874
# inclusts <listiterator object at 0x7f871769df90>
# 3000 3250 4874
# inclusts <listiterator object at 0x7f871769df90>
# 3250 3500 4874
# inclusts <listiterator object at 0x7f871769df90>
# 3500 3750 4874
# inclusts <listiterator object at 0x7f871769df90>
# 3750 4000 4874
# inclusts <listiterator object at 0x7f871769df90>
# 4000 4250 4874
# inclusts <listiterator object at 0x7f871769df90>
# 4250 4500 4874
# inclusts <listiterator object at 0x7f871769df90>
# 4500 4750 4874
# inclusts <listiterator object at 0x7f871769df90>
# 4750 5000 4874
# inclusts <listiterator object at 0x7f874b081150>
# 0 250 4377
# inclusts <listiterator object at 0x7f874b081150>
# 250 500 4377
# inclusts <listiterator object at 0x7f874b081150>
# 500 750 4377
# inclusts <listiterator object at 0x7f874b081150>
# 750 1000 4377
# inclusts <listiterator object at 0x7f874b081150>
# 1000 1250 4377
# inclusts <listiterator object at 0x7f874b081150>
# 1250 1500 4377
# inclusts <listiterator object at 0x7f874b081150>
# 1500 1750 4377
# inclusts <listiterator object at 0x7f874b081150>
# 1750 2000 4377
# inclusts <listiterator object at 0x7f874b081150>
# 2000 2250 4377
# inclusts <listiterator object at 0x7f874b081150>
# 2250 2500 4377
# inclusts <listiterator object at 0x7f874b081150>
# 2500 2750 4377
# inclusts <listiterator object at 0x7f874b081150>
# 2750 3000 4377
# inclusts <listiterator object at 0x7f874b081150>
# 3000 3250 4377
# inclusts <listiterator object at 0x7f874b081150>
# 3250 3500 4377
# inclusts <listiterator object at 0x7f874b081150>
# 3500 3750 4377
# inclusts <listiterator object at 0x7f874b081150>
# 3750 4000 4377
# inclusts <listiterator object at 0x7f874b081150>
# 4000 4250 4377
# inclusts <listiterator object at 0x7f874b081150>
# 4250 4500 4377
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 6333
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 6333
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 6333
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 6333
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 6333
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 6333
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 6333
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 6247
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 6247
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 6247
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 6247
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 6247
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 6247
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 6247
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 6519
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 6519
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 6519
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 6519
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 6519
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 6519
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 6519
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 7230
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 7230
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 7230
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 7230
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 7230
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 7230
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 7230
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 7230
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 6578
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 6578
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 6578
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 6578
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 6578
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 6578
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 6578
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 7650
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 7650
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 7650
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 7650
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 7650
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 7650
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 7650
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 7650
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 7549
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 7549
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 7549
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 7549
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 7549
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 7549
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 7549
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 7549
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 5777
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 5777
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 5777
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 5777
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 5777
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 5777
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 7250
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 7250
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 7250
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 7250
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 7250
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 7250
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 7250
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 7250
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 7304
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 7304
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 7304
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 7304
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 7304
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 7304
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 7304
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 7304
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 8528
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 8528
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 8528
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 8528
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 8528
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 8528
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 8528
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 8528
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 8528
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 7584
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 7584
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 7584
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 7584
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 7584
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 7584
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 7584
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 7584
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 8314
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 8314
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 8314
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 8314
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 8314
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 8314
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 8314
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 8314
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 8314
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 8481
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 8481
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 8481
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 8481
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 8481
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 8481
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 8481
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 8481
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 8481
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 5729
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 5729
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 5729
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 5729
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 5729
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 5729
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 8130
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 8130
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 8130
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 8130
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 8130
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 8130
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 8130
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 8130
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 8130
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 7967
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 7967
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 7967
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 7967
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 7967
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 7967
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 7967
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 7967
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 8955
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 8955
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 8955
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 8955
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 8955
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 8955
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 8955
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 8955
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 8955
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 7954
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 7954
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 7954
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 7954
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 7954
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 7954
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 7954
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 7954
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 8962
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 8962
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 8962
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 8962
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 8962
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 8962
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 8962
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 8962
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 8962
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 7294
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 7294
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 7294
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 7294
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 7294
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 7294
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 7294
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 7294
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 9353
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 9353
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 9353
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 9353
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 9353
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 9353
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 9353
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 9353
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 9353
# inclusts <listiterator object at 0x7f874b081150>
# 9000 10000 9353
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 10394
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 10394
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 10394
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 10394
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 10394
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 10394
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 10394
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 10394
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 10394
# inclusts <listiterator object at 0x7f871769df90>
# 9000 10000 10394
# inclusts <listiterator object at 0x7f871769df90>
# 10000 11000 10394
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 8631
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 8631
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 8631
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 8631
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 8631
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 8631
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 8631
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 8631
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 8631
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 6643
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 6643
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 6643
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 6643
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 6643
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 6643
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 6643
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 8873
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 8873
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 8873
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 8873
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 8873
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 8873
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 8873
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 8873
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 8873
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 8410
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 8410
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 8410
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 8410
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 8410
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 8410
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 8410
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 8410
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 8410
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 10811
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 10811
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 10811
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 10811
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 10811
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 10811
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 10811
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 10811
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 10811
# inclusts <listiterator object at 0x7f874b081150>
# 9000 10000 10811
# inclusts <listiterator object at 0x7f874b081150>
# 10000 11000 10811
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 8683
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 8683
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 8683
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 8683
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 8683
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 8683
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 8683
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 8683
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 8683
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 8606
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 8606
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 8606
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 8606
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 8606
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 8606
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 8606
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 8606
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 8606
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 9777
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 9777
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 9777
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 9777
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 9777
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 9777
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 9777
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 9777
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 9777
# inclusts <listiterator object at 0x7f871769df90>
# 9000 10000 9777
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 6325
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 6325
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 6325
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 6325
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 6325
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 6325
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 6325
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 10410
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 10410
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 10410
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 10410
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 10410
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 10410
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 10410
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 10410
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 10410
# inclusts <listiterator object at 0x7f871769df90>
# 9000 10000 10410
# inclusts <listiterator object at 0x7f871769df90>
# 10000 11000 10410
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 10502
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 10502
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 10502
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 10502
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 10502
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 10502
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 10502
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 10502
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 10502
# inclusts <listiterator object at 0x7f874b081150>
# 9000 10000 10502
# inclusts <listiterator object at 0x7f874b081150>
# 10000 11000 10502
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 8355
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 8355
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 8355
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 8355
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 8355
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 8355
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 8355
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 8355
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 8355
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 7992
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 7992
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 7992
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 7992
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 7992
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 7992
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 7992
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 7992
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 8938
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 8938
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 8938
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 8938
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 8938
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 8938
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 8938
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 8938
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 8938
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 9522
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 9522
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 9522
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 9522
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 9522
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 9522
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 9522
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 9522
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 9522
# inclusts <listiterator object at 0x7f874b081150>
# 9000 10000 9522
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 10808
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 10808
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 10808
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 10808
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 10808
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 10808
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 10808
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 10808
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 10808
# inclusts <listiterator object at 0x7f871769df90>
# 9000 10000 10808
# inclusts <listiterator object at 0x7f871769df90>
# 10000 11000 10808
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 7811
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 7811
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 7811
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 7811
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 7811
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 7811
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 7811
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 7811
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 11406
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 11406
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 11406
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 11406
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 11406
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 11406
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 11406
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 11406
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 11406
# inclusts <listiterator object at 0x7f871769df90>
# 9000 10000 11406
# inclusts <listiterator object at 0x7f871769df90>
# 10000 11000 11406
# inclusts <listiterator object at 0x7f871769df90>
# 11000 12000 11406
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 12836
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 12836
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 12836
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 12836
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 12836
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 12836
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 12836
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 12836
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 12836
# inclusts <listiterator object at 0x7f874b081150>
# 9000 10000 12836
# inclusts <listiterator object at 0x7f874b081150>
# 10000 11000 12836
# inclusts <listiterator object at 0x7f874b081150>
# 11000 12000 12836
# inclusts <listiterator object at 0x7f874b081150>
# 12000 13000 12836
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 7821
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 7821
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 7821
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 7821
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 7821
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 7821
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 7821
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 7821
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 11064
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 11064
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 11064
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 11064
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 11064
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 11064
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 11064
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 11064
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 11064
# inclusts <listiterator object at 0x7f874b081150>
# 9000 10000 11064
# inclusts <listiterator object at 0x7f874b081150>
# 10000 11000 11064
# inclusts <listiterator object at 0x7f874b081150>
# 11000 12000 11064
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 11036
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 11036
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 11036
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 11036
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 11036
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 11036
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 11036
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 11036
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 11036
# inclusts <listiterator object at 0x7f871769df90>
# 9000 10000 11036
# inclusts <listiterator object at 0x7f871769df90>
# 10000 11000 11036
# inclusts <listiterator object at 0x7f871769df90>
# 11000 12000 11036
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 8982
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 8982
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 8982
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 8982
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 8982
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 8982
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 8982
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 8982
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 8982
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 12997
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 12997
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 12997
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 12997
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 12997
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 12997
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 12997
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 12997
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 12997
# inclusts <listiterator object at 0x7f871769df90>
# 9000 10000 12997
# inclusts <listiterator object at 0x7f871769df90>
# 10000 11000 12997
# inclusts <listiterator object at 0x7f871769df90>
# 11000 12000 12997
# inclusts <listiterator object at 0x7f871769df90>
# 12000 13000 12997
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 10119
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 10119
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 10119
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 10119
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 10119
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 10119
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 10119
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 10119
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 10119
# inclusts <listiterator object at 0x7f874b081150>
# 9000 10000 10119
# inclusts <listiterator object at 0x7f874b081150>
# 10000 11000 10119
# inclusts <listiterator object at 0x7f87176e71d0>
# 0 1000 11130
# inclusts <listiterator object at 0x7f87176e71d0>
# 1000 2000 11130
# inclusts <listiterator object at 0x7f87176e71d0>
# 2000 3000 11130
# inclusts <listiterator object at 0x7f87176e71d0>
# 3000 4000 11130
# inclusts <listiterator object at 0x7f87176e71d0>
# 4000 5000 11130
# inclusts <listiterator object at 0x7f87176e71d0>
# 5000 6000 11130
# inclusts <listiterator object at 0x7f87176e71d0>
# 6000 7000 11130
# inclusts <listiterator object at 0x7f87176e71d0>
# 7000 8000 11130
# inclusts <listiterator object at 0x7f87176e71d0>
# 8000 9000 11130
# inclusts <listiterator object at 0x7f87176e71d0>
# 9000 10000 11130
# inclusts <listiterator object at 0x7f87176e71d0>
# 10000 11000 11130
# inclusts <listiterator object at 0x7f87176e71d0>
# 11000 12000 11130
# inclusts <listiterator object at 0x7f87176e7150>
# 0 1000 11769
# inclusts <listiterator object at 0x7f87176e7150>
# 1000 2000 11769
# inclusts <listiterator object at 0x7f87176e7150>
# 2000 3000 11769
# inclusts <listiterator object at 0x7f87176e7150>
# 3000 4000 11769
# inclusts <listiterator object at 0x7f87176e7150>
# 4000 5000 11769
# inclusts <listiterator object at 0x7f87176e7150>
# 5000 6000 11769
# inclusts <listiterator object at 0x7f87176e7150>
# 6000 7000 11769
# inclusts <listiterator object at 0x7f87176e7150>
# 7000 8000 11769
# inclusts <listiterator object at 0x7f87176e7150>
# 8000 9000 11769
# inclusts <listiterator object at 0x7f87176e7150>
# 9000 10000 11769
# inclusts <listiterator object at 0x7f87176e7150>
# 10000 11000 11769
# inclusts <listiterator object at 0x7f87176e7150>
# 11000 12000 11769
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 12534
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 12534
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 12534
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 12534
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 12534
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 12534
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 12534
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 12534
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 12534
# inclusts <listiterator object at 0x7f871769df90>
# 9000 10000 12534
# inclusts <listiterator object at 0x7f871769df90>
# 10000 11000 12534
# inclusts <listiterator object at 0x7f871769df90>
# 11000 12000 12534
# inclusts <listiterator object at 0x7f871769df90>
# 12000 13000 12534
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 13001
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 13001
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 13001
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 13001
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 13001
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 13001
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 13001
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 13001
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 13001
# inclusts <listiterator object at 0x7f874b081150>
# 9000 10000 13001
# inclusts <listiterator object at 0x7f874b081150>
# 10000 11000 13001
# inclusts <listiterator object at 0x7f874b081150>
# 11000 12000 13001
# inclusts <listiterator object at 0x7f874b081150>
# 12000 13000 13001
# inclusts <listiterator object at 0x7f874b081150>
# 13000 14000 13001
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 14281
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 14281
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 14281
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 14281
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 14281
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 14281
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 14281
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 14281
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 14281
# inclusts <listiterator object at 0x7f871769df90>
# 9000 10000 14281
# inclusts <listiterator object at 0x7f871769df90>
# 10000 11000 14281
# inclusts <listiterator object at 0x7f871769df90>
# 11000 12000 14281
# inclusts <listiterator object at 0x7f871769df90>
# 12000 13000 14281
# inclusts <listiterator object at 0x7f871769df90>
# 13000 14000 14281
# inclusts <listiterator object at 0x7f871769df90>
# 14000 15000 14281
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 14734
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 14734
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 14734
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 14734
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 14734
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 14734
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 14734
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 14734
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 14734
# inclusts <listiterator object at 0x7f874b081150>
# 9000 10000 14734
# inclusts <listiterator object at 0x7f874b081150>
# 10000 11000 14734
# inclusts <listiterator object at 0x7f874b081150>
# 11000 12000 14734
# inclusts <listiterator object at 0x7f874b081150>
# 12000 13000 14734
# inclusts <listiterator object at 0x7f874b081150>
# 13000 14000 14734
# inclusts <listiterator object at 0x7f874b081150>
# 14000 15000 14734
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 14082
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 14082
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 14082
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 14082
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 14082
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 14082
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 14082
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 14082
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 14082
# inclusts <listiterator object at 0x7f871769df90>
# 9000 10000 14082
# inclusts <listiterator object at 0x7f871769df90>
# 10000 11000 14082
# inclusts <listiterator object at 0x7f871769df90>
# 11000 12000 14082
# inclusts <listiterator object at 0x7f871769df90>
# 12000 13000 14082
# inclusts <listiterator object at 0x7f871769df90>
# 13000 14000 14082
# inclusts <listiterator object at 0x7f871769df90>
# 14000 15000 14082
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 8718
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 8718
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 8718
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 8718
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 8718
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 8718
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 8718
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 8718
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 8718
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 15928
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 15928
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 15928
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 15928
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 15928
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 15928
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 15928
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 15928
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 15928
# inclusts <listiterator object at 0x7f871769df90>
# 9000 10000 15928
# inclusts <listiterator object at 0x7f871769df90>
# 10000 11000 15928
# inclusts <listiterator object at 0x7f871769df90>
# 11000 12000 15928
# inclusts <listiterator object at 0x7f871769df90>
# 12000 13000 15928
# inclusts <listiterator object at 0x7f871769df90>
# 13000 14000 15928
# inclusts <listiterator object at 0x7f871769df90>
# 14000 15000 15928
# inclusts <listiterator object at 0x7f871769df90>
# 15000 16000 15928
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 13940
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 13940
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 13940
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 13940
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 13940
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 13940
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 13940
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 13940
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 13940
# inclusts <listiterator object at 0x7f874b081150>
# 9000 10000 13940
# inclusts <listiterator object at 0x7f874b081150>
# 10000 11000 13940
# inclusts <listiterator object at 0x7f874b081150>
# 11000 12000 13940
# inclusts <listiterator object at 0x7f874b081150>
# 12000 13000 13940
# inclusts <listiterator object at 0x7f874b081150>
# 13000 14000 13940
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 13684
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 13684
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 13684
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 13684
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 13684
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 13684
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 13684
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 13684
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 13684
# inclusts <listiterator object at 0x7f871769df90>
# 9000 10000 13684
# inclusts <listiterator object at 0x7f871769df90>
# 10000 11000 13684
# inclusts <listiterator object at 0x7f871769df90>
# 11000 12000 13684
# inclusts <listiterator object at 0x7f871769df90>
# 12000 13000 13684
# inclusts <listiterator object at 0x7f871769df90>
# 13000 14000 13684
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 14199
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 14199
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 14199
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 14199
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 14199
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 14199
# inclusts <listiterator object at 0x7f874b081150>
# 6000 7000 14199
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 14199
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 14199
# inclusts <listiterator object at 0x7f874b081150>
# 9000 10000 14199
# inclusts <listiterator object at 0x7f874b081150>
# 10000 11000 14199
# inclusts <listiterator object at 0x7f874b081150>
# 11000 12000 14199
# inclusts <listiterator object at 0x7f874b081150>
# 12000 13000 14199
# inclusts <listiterator object at 0x7f874b081150>
# 13000 14000 14199
# inclusts <listiterator object at 0x7f874b081150>
# 14000 15000 14199
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 14069
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 14069
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 14069
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 14069
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 14069
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 14069
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 14069
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 14069
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 14069
# inclusts <listiterator object at 0x7f871769df90>
# 9000 10000 14069
# inclusts <listiterator object at 0x7f871769df90>
# 10000 11000 14069
# inclusts <listiterator object at 0x7f871769df90>
# 11000 12000 14069
# inclusts <listiterator object at 0x7f871769df90>
# 12000 13000 14069
# inclusts <listiterator object at 0x7f871769df90>
# 13000 14000 14069
# inclusts <listiterator object at 0x7f871769df90>
# 14000 15000 14069
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 12259
# ...
# 6000 7000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 7000 8000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 8000 9000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 9000 10000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 10000 11000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 11000 12000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 12000 13000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 13000 14000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 14000 15000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 15000 16000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 16000 17000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 17000 18000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 18000 19000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 19000 20000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 20000 21000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 21000 22000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 22000 23000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 23000 24000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 24000 25000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 25000 26000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 26000 27000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 27000 28000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 28000 29000 29158
# inclusts <listiterator object at 0x7f874b081150>
# 29000 30000 29158
# inclusts <listiterator object at 0x7f871769df90>
# 0 1000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 1000 2000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 2000 3000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 3000 4000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 4000 5000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 5000 6000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 6000 7000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 7000 8000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 8000 9000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 9000 10000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 10000 11000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 11000 12000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 12000 13000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 13000 14000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 14000 15000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 15000 16000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 16000 17000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 17000 18000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 18000 19000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 19000 20000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 20000 21000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 21000 22000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 22000 23000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 23000 24000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 24000 25000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 25000 26000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 26000 27000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 27000 28000 28559
# inclusts <listiterator object at 0x7f871769df90>
# 28000 29000 28559
# inclusts <listiterator object at 0x7f874b081150>
# 0 1000 5051
# inclusts <listiterator object at 0x7f874b081150>
# 1000 2000 5051
# inclusts <listiterator object at 0x7f874b081150>
# 2000 3000 5051
# inclusts <listiterator object at 0x7f874b081150>
# 3000 4000 5051
# inclusts <listiterator object at 0x7f874b081150>
# 4000 5000 5051
# inclusts <listiterator object at 0x7f874b081150>
# 5000 6000 5051
#                             state  reads_raw  reads_filtered  clusters_total  \
# FGXCONTROL                      3     126378          103847            5001
# acerfolium_ELS88                3      23232           17800           14001
# acutifolium_D11_MEX_005         3      12292           10140            7001
# acutifolium_DRY3_MEX_006        3      33137           25261           21001
# amplificatum_D3_SAN_156003      3      22284           17305           14001
# anamensis_C6_PWS_2094           3       6685            5084            4251
# beccarii_combinedX              3      11901           10086            8001
# betulifolium                    3      11792            9597            5001
# bitchuense_combined             3      14212           11994            8001
# carlesii_D1_BP_001              3      27172           23293           15001
# cassinoides_ELS2                3      14056           11883            8001
# cassinoides_ELS29               3      12591            9800            8001
# cassinoides_ELS3                3      10132            8086            6001
# cassinoides_ELS50               3      11051            8888            7001
# cassinoides_ELS77               3      17391           13218           10001
# cassinoides_ELS79               3      14225           10386            8001
# cassinoides_LS54                3       7920            5820            4751
# cassinoides_YU08                3       5879            4527            3751
# cinnamomifolium_PWS2105X        3      22479           18427           14001
# clemensiae_DRY6_PWS_2135        3      21398           17533           13001
# coriaceum_combined              3      16501           13378            8001
# cylindricum_DRY1_WC_268         3      40868           31633           25001
# davidii_D32_WC_269              3      22173           18781           14001
# dentatum_AA_5070_1A             3      11451            9848            7001
# dentatum_ELS15                  3      14002           11686           10001
# dentatum_ELS27                  3      35581           28510           23001
# dentatum_ELS4                   3      26792           21357           18001
# dentatum_ELS52                  3      25205           19831           17001
# dentatum_ELS72                  3      18476           14620           12001
# dentatum_ELS82                  3      26842           21768           16001
# ...                           ...        ...             ...             ...
# propiinquum_combined            3      17025           13188            9001
# propinquum_DRY4_WC_276          3      22628           18727           14001
# prunifolium_AA_22586A           3      20650           17703            8001
# prunifolium_ELS57               3      16386           13978           11001
# punctatum_D19_PWS_2097          3      22294           17786           13001
# recognitum_AA_1471_83B          3      15531           12786            7001
# rhytidophyllum                  3      17229           14246            7001
# rufidulum_AA_21418A             3      13407           10103            5001
# rufidulum_ELS1                  3      10705            8590            7001
# rufidulum_ELS17                 3      12412            8808            7001
# rufidulum_ELS25                 3      12941            9393            7001
# sambucina_D20_PWS_2100          3      16882           14105           11001
# sargentii_RCW19                 3       9648            8137            6001
# sempervirens_combined           3      10040            8242            6001
# setigerum                       3      21794           17593           10001
# sieboldii_AA_616_6B             3       8405            6948            4251
# sulc_acut_hyb_D7_MEX_001        3      26277           20955           17001
# sulc_acut_hyb_D8_MEX_002        3      20250           15438           12001
# sulcatum_D10_MEX_004            3      39518           28005           24001
# sulcatum_D9_MEX_003             3      45904           33968           29001
# suspensum_C5_MJD_111711         3      12734           10277            7001
# sympodiale_D18_KFC_1932         3      24856           20135           16001
# taiwanianum_TW1_KFC_1952        3      38238           30240           25001
# tashiori_D30_TET_YAH            3      37508           29260           25001
# tinus_D33_WC_277                3      21717           17234           12001
# triphyllum_D13_PWS_1783         3      13802           11631            8001
# urceolatum_MJD_Japan_8          3      13891           11014            8001
# veitchii                        3      15273           12965            8001
# vernicosum_D21_PWS_2123         3      14880           12105           10001
# wrightii_D31_MJDJP_1            3      15786           13231           10001
#
#                             clusters_kept  hetero_est  error_est  \
# FGXCONTROL                           4481         NaN        NaN
# acerfolium_ELS88                       43         NaN        NaN
# acutifolium_D11_MEX_005                41         NaN        NaN
# acutifolium_DRY3_MEX_006               62         NaN        NaN
# amplificatum_D3_SAN_156003             87         NaN        NaN
# anamensis_C6_PWS_2094                   9         NaN        NaN
# beccarii_combinedX                     34         NaN        NaN
# betulifolium                          113         NaN        NaN
# bitchuense_combined                    81         NaN        NaN
# carlesii_D1_BP_001                    247         NaN        NaN
# cassinoides_ELS2                       51         NaN        NaN
# cassinoides_ELS29                      20         NaN        NaN
# cassinoides_ELS3                       31         NaN        NaN
# cassinoides_ELS50                      29         NaN        NaN
# cassinoides_ELS77                      48         NaN        NaN
# cassinoides_ELS79                      42         NaN        NaN
# cassinoides_LS54                       28         NaN        NaN
# cassinoides_YU08                       21         NaN        NaN
# cinnamomifolium_PWS2105X              134         NaN        NaN
# clemensiae_DRY6_PWS_2135               76         NaN        NaN
# coriaceum_combined                    176         NaN        NaN
# cylindricum_DRY1_WC_268                54         NaN        NaN
# davidii_D32_WC_269                     88         NaN        NaN
# dentatum_AA_5070_1A                    46         NaN        NaN
# dentatum_ELS15                          5         NaN        NaN
# dentatum_ELS27                         49         NaN        NaN
# dentatum_ELS4                          25         NaN        NaN
# dentatum_ELS52                         35         NaN        NaN
# dentatum_ELS72                         28         NaN        NaN
# dentatum_ELS82                         54         NaN        NaN
# ...                                   ...         ...        ...
# propiinquum_combined                  149         NaN        NaN
# propinquum_DRY4_WC_276                102         NaN        NaN
# prunifolium_AA_22586A                 222         NaN        NaN
# prunifolium_ELS57                      46         NaN        NaN
# punctatum_D19_PWS_2097                 75         NaN        NaN
# recognitum_AA_1471_83B                205         NaN        NaN
# rhytidophyllum                        252         NaN        NaN
# rufidulum_AA_21418A                   177         NaN        NaN
# rufidulum_ELS1                         30         NaN        NaN
# rufidulum_ELS17                        22         NaN        NaN
# rufidulum_ELS25                        46         NaN        NaN
# sambucina_D20_PWS_2100                 79         NaN        NaN
# sargentii_RCW19                       101         NaN        NaN
# sempervirens_combined                  58         NaN        NaN
# setigerum                             222         NaN        NaN
# sieboldii_AA_616_6B                    70         NaN        NaN
# sulc_acut_hyb_D7_MEX_001               59         NaN        NaN
# sulc_acut_hyb_D8_MEX_002               45         NaN        NaN
# sulcatum_D10_MEX_004                   28         NaN        NaN
# sulcatum_D9_MEX_003                    42         NaN        NaN
# suspensum_C5_MJD_111711                64         NaN        NaN
# sympodiale_D18_KFC_1932                32         NaN        NaN
# taiwanianum_TW1_KFC_1952               62         NaN        NaN
# tashiori_D30_TET_YAH                   28         NaN        NaN
# tinus_D33_WC_277                      113         NaN        NaN
# triphyllum_D13_PWS_1783                37         NaN        NaN
# urceolatum_MJD_Japan_8                 59         NaN        NaN
# veitchii                              146         NaN        NaN
# vernicosum_D21_PWS_2123                 9         NaN        NaN
# wrightii_D31_MJDJP_1                   48         NaN        NaN
#
#                             reads_consens
# FGXCONTROL                            NaN
# acerfolium_ELS88                      NaN
# acutifolium_D11_MEX_005               NaN
# acutifolium_DRY3_MEX_006              NaN
# amplificatum_D3_SAN_156003            NaN
# anamensis_C6_PWS_2094                 NaN
# beccarii_combinedX                    NaN
# betulifolium                          NaN
# bitchuense_combined                   NaN
# carlesii_D1_BP_001                    NaN
# cassinoides_ELS2                      NaN
# cassinoides_ELS29                     NaN
# cassinoides_ELS3                      NaN
# cassinoides_ELS50                     NaN
# cassinoides_ELS77                     NaN
# cassinoides_ELS79                     NaN
# cassinoides_LS54                      NaN
# cassinoides_YU08                      NaN
# cinnamomifolium_PWS2105X              NaN
# clemensiae_DRY6_PWS_2135              NaN
# coriaceum_combined                    NaN
# cylindricum_DRY1_WC_268               NaN
# davidii_D32_WC_269                    NaN
# dentatum_AA_5070_1A                   NaN
# dentatum_ELS15                        NaN
# dentatum_ELS27                        NaN
# dentatum_ELS4                         NaN
# dentatum_ELS52                        NaN
# dentatum_ELS72                        NaN
# dentatum_ELS82                        NaN
# ...                                   ...
# propiinquum_combined                  NaN
# propinquum_DRY4_WC_276                NaN
# prunifolium_AA_22586A                 NaN
# prunifolium_ELS57                     NaN
# punctatum_D19_PWS_2097                NaN
# recognitum_AA_1471_83B                NaN
# rhytidophyllum                        NaN
# rufidulum_AA_21418A                   NaN
# rufidulum_ELS1                        NaN
# rufidulum_ELS17                       NaN
# rufidulum_ELS25                       NaN
# sambucina_D20_PWS_2100                NaN
# sargentii_RCW19                       NaN
# sempervirens_combined                 NaN
# setigerum                             NaN
# sieboldii_AA_616_6B                   NaN
# sulc_acut_hyb_D7_MEX_001              NaN
# sulc_acut_hyb_D8_MEX_002              NaN
# sulcatum_D10_MEX_004                  NaN
# sulcatum_D9_MEX_003                   NaN
# suspensum_C5_MJD_111711               NaN
# sympodiale_D18_KFC_1932               NaN
# taiwanianum_TW1_KFC_1952              NaN
# tashiori_D30_TET_YAH                  NaN
# tinus_D33_WC_277                      NaN
# triphyllum_D13_PWS_1783               NaN
# urceolatum_MJD_Japan_8                NaN
# veitchii                              NaN
# vernicosum_D21_PWS_2123               NaN
# wrightii_D31_MJDJP_1                  NaN
#
# [96 rows x 8 columns]
# /home/deren/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
import ipyrad.plotting as ipp

# %%
print data1.samples['2E_0'].depths.statmin

# %%
ipp.depthplot(data1, ['2E_0', '2F_0'])

# %%
data1.samples["2E_0"].depths['total'].shape

# %%
## run step 3 to cluster reads within samples using vsearch
data2.step3()  # ["2H_0", "2G_0"])

## print the results
print data2.stats

# %% [markdown]
# ### Branching Assembly objects
# And you can see below that the two Assembly objects are now working with several shared directories (working, fastq, edits) but with different clust directories (clust_0.85 and clust_0.9).

# %%
print "data1 directories:"
for (i,j) in data1.dirs.items():
    print "{}\t{}".format(i, j)
    
print "\ndata2 directories:"
for (i,j) in data2.dirs.items():
    print "{}\t{}".format(i, j)
    
## TODO: raw and fastq dirs...

# %%
data1.statsfiles

# %%
data1.stats.to_csv("data1_results.csv")

# %%
cat data1_results.csv

# %% [markdown]
# ### Example of plotting with _ipyrad_
# There are a a few simple plotting functions in _ipyrad_ useful for visualizing results. These are in the module `ipyrad.plotting`. Below is an interactive plot for visualizing the distributions of coverages across the 12 samples in the test data set.

# %%
import ipyrad.plotting as iplot

## plot for one or more selected samples
iplot.depthplot(data1, ["1A_0", "1B_0"])

## plot for all samples in data1
#iplot.depthplot(data1)

## save plot as pdf and html
iplot.depthplot(data1, outprefix="testfig")

# %% [markdown]
# ### Step 4: Joint estimation of heterozygosity and error rate

# %%
## run step 4
data1.step4()

## print the results
print data1.stats

# %% [markdown]
# ### Step 5: Consensus base calls

# %%
#import ipyrad as ip

## reload autosaved data. In case you quit and came back 
#data1 = ip.load_dataobj("test_rad/data1.assembly")

# %%
## run step 5
data1.step5()

## print the results
print data1.stats

# %%
data1.stats

# %% [markdown]
# ### Quick parameter explanations are always on-hand

# %%
ip.get_params_info(10)

# %% [markdown]
# ### Log history
# A common problem after struggling through an analysis is that you find you've completely forgotten what parameters you used at what point, and when you changed them. The log history time stamps all calls to `set_params()`, as well as calls to `step` methods. It also records copies/branching of data objects.

# %%
for i in data1.log:
    print i

# %% [markdown]
# ### Saving Assembly objects
# Assembly objects can be saved and loaded so that interactive analyses can be started, stopped, and returned to quite easily. The format of these saved files is a serialized 'dill' object used by Python. Individual Sample objects are saved within Assembly objects. These objects to not contain the actual sequence data, but only link to it, and so are not very large. The information contained includes parameters and the log of Assembly objects, and the statistics and state of Sample objects. Assembly objects are autosaved each time an assembly `step` function is called, but you can also create your own checkpoints with the `save` command.

# %%
## save assembly object
#ip.save_assembly("data1.p")

## load assembly object
#data = ip.load_assembly("data1.p")
#print data.name
